# %%
# !nvidia-smi
# Out:
# Wed Mar  5 12:05:16 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet

import roboflow

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("husham-eina").project("qatari_license_plate_detection")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# /content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets
# You are already logged into Roboflow. To make a different login,run roboflow.login(force=True).
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Qatari_License_Plate_Detection-2 in yolov8:: 100%|██████████| 4030/4030 [00:00<00:00, 5701.13it/s]

# %% [markdown]
# ## Custom Training

# %%
# !pip install ultralytics

# %cd {/content/{HOME}/datasets/{HOME}/datasets}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import os

for item in os.listdir():
    print(os.path.abspath(item))
# Out:
# /content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/yolov8s.pt
# /content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/Qatari_License_Plate_Detection-2
# /content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/yolo11n.pt
# /content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/runs

# %%
# !ls /content/
# Out:
# {HOME}	Qatari_License_Plate_Detection-2  sample_data

# %%
from IPython.display import Image
import os

# Replace 'your_home_folder' with the actual folder name
HOME = "{HOME}"  # Change this to the correct folder name

# Construct the full path
conf_matrix_path = f"/content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/runs/detect/train/confusion_matrix.png"

# Check if the file exists before displaying it
if os.path.exists(conf_matrix_path):
    display(Image(filename=conf_matrix_path, width=600))
else:
    print(f"Error: File '{conf_matrix_path}' not found.")

# %%
from IPython.display import Image
import os

# Replace 'your_home_folder' with the actual folder name
HOME = "{HOME}"  # Change this to the correct folder name

# Construct the full path
conf_matrix_path = f"/content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/runs/detect/train/results.png"

# Check if the file exists before displaying it
if os.path.exists(conf_matrix_path):
    display(Image(filename=conf_matrix_path, width=600))
else:
    print(f"Error: File '{conf_matrix_path}' not found.")

# %%
from IPython.display import Image
import os

# Replace 'your_home_folder' with the actual folder name
HOME = "{HOME}"  # Change this to the correct folder name

# Construct the full path
conf_matrix_path = f"/content/{HOME}/datasets/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch0_pred.jpg"

# Check if the file exists before displaying it
if os.path.exists(conf_matrix_path):
    display(Image(filename=conf_matrix_path, width=600))
else:
    print(f"Error: File '{conf_matrix_path}' not found.")
